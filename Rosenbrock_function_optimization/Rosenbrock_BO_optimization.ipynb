# %% [markdown]
# <a href="https://colab.research.google.com/github/Nina-Konovalova/Bayesian-optimization/blob/main/Rosenbrock_function_optimization/Rosenbrock_BO_optimization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Install

# %%
! pip install GPy gpyopt
# Out:
# Collecting GPy
#   Downloading https://files.pythonhosted.org/packages/67/95/976598f98adbfa918a480cb2d643f93fb555ca5b6c5614f76b69678114c1/GPy-1.9.9.tar.gz (995kB)
#      |████████████████████████████████| 1.0MB 5.6MB/s
# Collecting gpyopt
#   Downloading https://files.pythonhosted.org/packages/52/be/669d505416d7e465b2aef7df3b58d590f56468c4f7dc50c91fe91b8a78d9/GPyOpt-1.2.6.tar.gz (56kB)
#      |████████████████████████████████| 61kB 6.1MB/s
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from GPy) (1.19.5)
# Requirement already satisfied: scipy>=0.16 in /usr/local/lib/python3.6/dist-packages (from GPy) (1.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from GPy) (1.15.0)
# Collecting paramz>=0.9.0
#   Downloading https://files.pythonhosted.org/packages/d8/37/4abbeb78d30f20d3402887f46e6e9f3ef32034a9dea65d243654c82c8553/paramz-0.9.5.tar.gz (71kB)
#      |████████████████████████████████| 71kB 6.0MB/s
# Requirement already satisfied: decorator>=4.0.10 in /usr/local/lib/python3.6/dist-packages (from paramz>=0.9.0->GPy) (4.4.2)
# Building wheels for collected packages: GPy, gpyopt, paramz
#   Building wheel for GPy (setup.py) ... done
#   Created wheel for GPy: filename=GPy-1.9.9-cp36-cp36m-linux_x86_64.whl size=2633925 sha256=b10a01e35037df224360558cfc8f601dc99d6bfe0c09e87ca3da5fe018a72846
#   Stored in directory: /root/.cache/pip/wheels/5d/36/66/2b58860c84c9f2b51615da66bfd6feeddbc4e04d887ff96dfa
#   Building wheel for gpyopt (setup.py) ... done
#   Created wheel for gpyopt: filename=GPyOpt-1.2.6-cp36-none-any.whl size=83623 sha256=737c743afc4b38f8c631601447efa85a38f41a663bd924357af6d1ca96fbf93b
#   Stored in directory: /root/.cache/pip/wheels/b2/00/69/cfa967a125cf25e66f644be6193ad6f0edf231147879ad714f
#   Building wheel for paramz (setup.py) ... done
#   Created wheel for paramz: filename=paramz-0.9.5-cp36-none-any.whl size=102552 sha256=b961c1287ce964574f0f90e8199ba7ddb796f56565318cd0c51dcf79c555e866
#   Stored in directory: /root/.cache/pip/wheels/c8/4a/0e/6e0dc85541825f991c431619e25b870d4b812c911214690cf8
# Successfully built GPy gpyopt paramz
# Installing collected packages: paramz, GPy, gpyopt
# Successfully installed GPy-1.9.9 gpyopt-1.2.6 paramz-0.9.5

# %% [markdown]
# ## Import main libs

# %%
# %pylab inline  
import GPy
import GPyOpt
import numpy as np
from numpy.random import seed
seed(12354)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Main part

# %%
#bounds for our function
space =[{'name': 'var_1', 'type': 'continuous', 'domain': (-3,3)},
        {'name': 'var_2', 'type': 'continuous', 'domain': (-3,3)}]

# function we want to optimize
def Rosenbrock (x):
      x = x.reshape(-1,1)
      return (1-x[0])**2 + 100.0*(x[1] - x[0]**2)**2

# Creation of the object that we will use to run BO.
# BO object
kernel = GPy.kern.RBF(1, 1.5, 2)
model = GPyOpt.models.GPModel(optimize_restarts=3,exact_feval = True, verbose=True) #GP model without noize and with 3 restarts

myBopt = GPyOpt.methods.BayesianOptimization(f = Rosenbrock,        # function to optimize       
                                             domain = space,        # box-constraints of the problem
                                             model = model,
                                             initial_design_numdata = 60, #number of initial points
                                             initial_design_type = 'random',
                                             normalize_Y = False,
                                             verbosity = True,
                                             acquisition_type ='MPI') # acquisition = Expected improvement


#greed for function
xx = np.arange(-3,3.1,0.1)

grid_x, grid_y = np.meshgrid(xx,xx)

surf = np.zeros((grid_x.shape[1], grid_x.shape[1]))
for i in range (grid_x.shape[1]):
  for j in range (grid_x.shape[1]):
     surf[i][j] = Rosenbrock(np.array([grid_x[i][j],grid_y[i][j]]))

#--------------------------------------------------------
from matplotlib import cm
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.scatter(myBopt.X[:,0],myBopt.X[:,1],myBopt.Y, color = 'red', s=40, marker = '+')
ax.plot_surface(grid_x, grid_y, surf, cmap=cm.viridis, linewidth=0, antialiased=False, alpha = 0.2)

fig.savefig('my_figure.png')
plt.show()
# Out:
# Using a model defined by the used.

# %% [markdown]
# ## BO Optimization

# %%
# Run the optimization (may take a few senconds)

myBopt.run_optimization(25)   # run optimization
# Out:
# Optimization restart 1/3, f = 571.8815753716982
# Optimization restart 2/3, f = 576.0120248404401
# Optimization restart 3/3, f = 419.2760575662252
# Optimization restart 1/3, f = 426.1942114299962
# Optimization restart 2/3, f = 581.2848563625273
# Optimization restart 3/3, f = 426.38462964934416
# Optimization restart 1/3, f = 430.7899528842149
# Optimization restart 2/3, f = 591.0082962158712
# Optimization restart 3/3, f = 435.689631910246
# Optimization restart 1/3, f = 436.405612609385
# Optimization restart 2/3, f = 433.13729077447346
# Optimization restart 3/3, f = 484.7127215194494
# Optimization restart 1/3, f = 439.24932961657186
# Optimization restart 2/3, f = 442.640650395372
# Optimization restart 3/3, f = 622.9603650624125
# Optimization restart 1/3, f = 444.3396819355925
# Optimization restart 2/3, f = 449.39105737623606
# Optimization restart 3/3, f = 619.3749875197782
# Optimization restart 1/3, f = 448.85167672248963
# Optimization restart 2/3, f = 480.0539594281384
# Optimization restart 3/3, f = 452.60099646615475
# Optimization restart 1/3, f = 448.55007609913304
# Optimization restart 2/3, f = 2302.8550892750204
# Optimization restart 3/3, f = 452.5870779820793
# Optimization restart 1/3, f = 451.9464765387659
# Optimization restart 2/3, f = 460.81258229950936
# Optimization restart 3/3, f = 461.35664068597123
# Optimization restart 1/3, f = 454.7464036571889
# Optimization restart 2/3, f = 648.1554435655082
# Optimization restart 3/3, f = 464.1272747284726
# Optimization restart 1/3, f = 459.13678585574456
# Optimization restart 2/3, f = 1328.1964117694415
# Optimization restart 3/3, f = 661.4384681699496
# Optimization restart 1/3, f = 461.0608529648253
# Optimization restart 2/3, f = 465.52552184215904
# Optimization restart 3/3, f = 457.7954614045898
# Optimization restart 1/3, f = 458.19059937362977
# Optimization restart 2/3, f = 679.141971528481
# Optimization restart 3/3, f = 674.3424677315493
# Optimization restart 1/3, f = 459.69019367190214
# Optimization restart 2/3, f = 1240.111571896202
# Optimization restart 3/3, f = 470.31321474559974
# Optimization restart 1/3, f = 463.7869542123006
# Optimization restart 2/3, f = 500.210763711171
# Optimization restart 3/3, f = 693.3234896152582
# Optimization restart 1/3, f = 468.84892381959406
# Optimization restart 2/3, f = 701.3292666036723
# Optimization restart 3/3, f = 472.75702149586255
# Optimization restart 1/3, f = 471.92330898246684
# Optimization restart 2/3, f = 517.6675587488768
# Optimization restart 3/3, f = 485.3657995995024
# Optimization restart 1/3, f = 473.5727188189774
# Optimization restart 2/3, f = 722.4223158101895
# Optimization restart 3/3, f = 717.5982683317491
# Optimization restart 1/3, f = 477.80005986446724
# Optimization restart 2/3, f = 487.5242735007834
# Optimization restart 3/3, f = 485.71747365416877
# Optimization restart 1/3, f = 480.5896759055205
# Optimization restart 2/3, f = 735.8844384671719
# Optimization restart 3/3, f = 736.8512526900557
# Optimization restart 1/3, f = 482.934746443935
# Optimization restart 2/3, f = 784.1810670652335
# Optimization restart 3/3, f = 480.6385761268901
# Optimization restart 1/3, f = 481.8907771617438
# Optimization restart 2/3, f = 818.1493741138029
# Optimization restart 3/3, f = 757.3669322327668
# Optimization restart 1/3, f = 482.24088343188583
# Optimization restart 2/3, f = 490.221119203621
# Optimization restart 3/3, f = 494.36868757609625
# Optimization restart 1/3, f = 484.04683114833034
# Optimization restart 2/3, f = 513.8475844555657
# Optimization restart 3/3, f = 484.5774243200349
# Optimization restart 1/3, f = 487.9215649023049
# Optimization restart 2/3, f = 778.5439111234599
# Optimization restart 3/3, f = 780.7045556805708
# Optimization restart 1/3, f = 490.83822015708756
# Optimization restart 2/3, f = 1616.3039796388073
# Optimization restart 3/3, f = 789.6847669729441

# %%
# resulting model after BO optimization
myBopt.model.model
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: GP regression<br>
# <b>Objective</b>: 490.83822015708756<br>
# <b>Number of Parameters</b>: 3<br>
# <b>Number of Optimization Parameters</b>: 2<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  GP_regression.         </b></th><th><b>            value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  Mat52.variance         </td><td class=tg-right>918132876.3270549</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  Mat52.lengthscale      </td><td class=tg-right> 9.75057723949825</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  Gaussian_noise.variance</td><td class=tg-right>            1e-06</td><td class=tg-center> +ve fixed </td><td class=tg-center>      </td></tr>
# </table>

# %% [markdown]
# ## Plots
#
# The first plot shows the distance between the last two collected observations at each iteration. This plot is useful to evaluate the convergence of the method. The second plot shows the best found value at each iteration. It is useful to compare different methods. The fastest the curve decreases the best is the method.

# %%
myBopt.plot_convergence()

# %%
myBopt.plot_acquisition()
# Out:
# Optimization restart 1/3, f = 490.83822015708756
# Optimization restart 2/3, f = 497.39570181867066
# Optimization restart 3/3, f = 505.6719052016357

# %%
Y_pred = np.zeros((grid_x.shape[1], grid_x.shape[1]))
for i in range (len(grid_x)):
    for j in range (len(grid_x)):
      Y_pred[i][j] = myBopt.model.model.predict(np.array([grid_x[i][j],grid_y[i][j]]).reshape(1,-1))[0][0][0]

# %%
from sklearn.metrics import mean_squared_error as mse
mse(surf, Y_pred)
# Out:
# 14325.10793107856

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.scatter(myBopt.X[:,0],myBopt.X[:,1],myBopt.Y, color = 'red', s=40, marker = '+')
ax.plot_surface(grid_x, grid_y, (Y_pred), cmap=cm.viridis, linewidth=0, antialiased=False, alpha = 0.2)

# %% [markdown]
# ## Result of optimization

# %%
np.round(myBopt.x_opt,2)
# Out:
# array([1.01, 1.02])

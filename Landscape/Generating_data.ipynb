# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import random

# %% [markdown]
# ## Normal distribution

# %%
def f_norm(sigma,mu,x):
    return 1/(sigma*np.sqrt(2*np.pi))*np.exp(-(x - mu)**2/(2*sigma**2))

# %% [markdown]
# ## Exponental distribution

# %%
def expon(a,x):
  return math.exp(-x**4/a**4)

# %% [markdown]
# ## Laplasian distribution

# %%
def lapl(x0,a,i):
  return 1/((i-x0)**2 + a**2)

#parametrs for this distribution c*lapl(a,b,i)

#a = np.random.randint(10,40)
#b = np.random.randint(5,10)
#c = np.random.randint(80,100)

# %% [markdown]
# ## Examples how to generate dataset

# %%
data = []

# %%
# sum of 1 or 2 normal distributions

def new_input (sigma,mu,a, sigma1,mu1, b):
    N = 51 
    x = []
    y = []
    t = 1
    num1 = 50000
    #f.write(str(N-1) + '\t'+ str(t) + '\n' + str(num1)+ '\t'+ str(t) +'\t' + str(20000)+ '\t'+ str(t) + '\n' )
    for i in range (N):
        x.append(i)
        y.append(a*f_norm(sigma,mu,i) + 0*f_norm(sigma1,mu1,i))
        #y.append(a*lapl(sigma,mu,i)) 
        #f.write (str(i) + '\t' + str(y[i]) + '\n')
    plt.plot(x,y)
    #f.close()
    return y

# %%
# sum of 1 or 2 or 3 normal distributions


def new_input1 (sigma,mu,a, sigma1,mu1, b,sigma2,mu2, c):
    N = 51 
    x = []
    y = []
    t = 1
    num1 = 50000
    #f.write(str(N-1) + '\t'+ str(t) + '\n' + str(num1)+ '\t'+ str(t) +'\t' + str(20000)+ '\t'+ str(t) + '\n' )
    for i in range (N):
        x.append(i)
        y.append(-a*f_norm(sigma,mu,i) - b*f_norm(sigma1,mu1,i) - c*f_norm(sigma2,mu2,i))
        
        #f.write (str(i) + '\t' + str(y[i]) + '\n')
    plt.plot(x,y)
    #f.close()
    return y

# %% [markdown]
# #### Data generation

# %%
for j in range (50):
    
    y = new_input(np.random.randint(5,15),np.random.randint(5,45), np.random.randint(40,70), np.random.randint(5,15),np.random.randint(5,45),np.random.randint(40,70))
    #y = new_input(np.random.randint(10,40),np.random.randint(5,10), np.random.randint(80,100), np.random.randint(5,15),np.random.randint(5,45),np.random.randint(40,70))
    #y = new_input1(np.random.randint(5,15),np.random.randint(5,45), np.random.randint(40,70),np.random.randint(5,15),np.random.randint(5,45),np.random.randint(40,70),np.random.randint(5,15),np.random.randint(5,45),np.random.randint(40,70))
    data.append(y)

# %% [markdown]
# #### Saving this data

# %%
dat = pd.DataFrame(data)
dat.to_csv('initial_data(2).csv')#, index = False)
# Out:
# (100, 51)

# %%
dat = pd.read_csv('experimental_data.csv')
dat
# Out:
#               0             1  ...            49            50
# 0 -7.559005e-01 -8.644391e-01  ... -2.232439e-01 -1.898153e-01
# 1  1.153929e+00  1.267118e+00  ...  3.135788e-02  2.451070e-02
# 2  5.201781e-01  6.963400e-01  ...  5.444914e-09  1.868690e-09
# 3 -1.983351e-03 -3.144721e-03  ... -1.337169e-01 -9.859669e-02
# 4  1.542306e+00  1.651379e+00  ...  1.342318e+00  1.192850e+00
# 5 -1.209021e+00 -1.310176e+00  ... -1.949469e+00 -1.742984e+00
# 6 -5.103093e-01 -5.857988e-01  ... -7.494322e-02 -7.101865e-02
# 7  5.655172e-02  5.954975e-02  ...  3.644444e-01  3.280000e-01
# 8 -6.582206e-08 -1.764551e-07  ... -4.133201e-01 -2.840705e-01
#
# [9 rows x 51 columns]
